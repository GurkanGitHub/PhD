# %%
import pandas as pd

# %%
df = pd.read_excel("D:/github/PhD/NumsWars.xlsx", sheet_name="Figure 1-7")

# %%
df.head()
# Out:
#   Selected Battle Statistics, 1805-1973 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                Battle       Date  Attacker*   Strength
# 1                            Austerlitz       1805     FRENCH      75000
# 2                             Auerstadt       1806  Prussians      50000
# 3                              Borodino       1812     FRENCH     130000
# 4                               Dresden       1813     FRENCH     100000
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0  Defender*   Strength        A/D        V/L
# 1     Allies      89000       0.84       0.84
# 2     FRENCH      30000       1.67        0.6
# 3   Russians     120000       1.08       1.08
# 4     Allies     150000       0.67       0.67

# %%
df.columns
# Out:
# Index(['Selected Battle Statistics, 1805-1973', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
df.loc[0, :][0:7].to_list()
# Out:
# ['Battle', 'Date', 'Attacker*', 'Strength', 'Defender*', 'Strength', 'A/D']

# %%
df.rename(columns=df.loc[0, :][0:8], inplace=True)
df.head()
# Out:
#        Battle  Date  Attacker*  Strength  Defender*  Strength   A/D   V/L
# 0      Battle  Date  Attacker*  Strength  Defender*  Strength   A/D   V/L
# 1  Austerlitz  1805     FRENCH     75000     Allies     89000  0.84  0.84
# 2   Auerstadt  1806  Prussians     50000     FRENCH     30000  1.67   0.6
# 3    Borodino  1812     FRENCH    130000   Russians    120000  1.08  1.08
# 4     Dresden  1813     FRENCH    100000     Allies    150000  0.67  0.67

# %%
df.columns
# Out:
# Index(['Battle', 'Date', 'Attacker*', 'Strength', 'Defender*', 'Strength',
#        'A/D', 'V/L'],
#       dtype='object')

# %%
df.columns= ['Battle', 'Date', 'Attacker*', 'Strength_Att', 'Defender*', 'Strength_Def',
       'A/D', 'V/L']

# %%
df.head()
# Out:
#        Battle  Date  Attacker* Strength_Att  Defender* Strength_Def   A/D  \
# 0      Battle  Date  Attacker*     Strength  Defender*     Strength   A/D
# 1  Austerlitz  1805     FRENCH        75000     Allies        89000  0.84
# 2   Auerstadt  1806  Prussians        50000     FRENCH        30000  1.67
# 3    Borodino  1812     FRENCH       130000   Russians       120000  1.08
# 4     Dresden  1813     FRENCH       100000     Allies       150000  0.67
#
#     V/L
# 0   V/L
# 1  0.84
# 2   0.6
# 3  1.08
# 4  0.67

# %%
df.drop(axis=0, index=0, inplace=True)
df.head()
# Out:
#        Battle  Date  Attacker* Strength_Att Defender* Strength_Def   A/D   V/L
# 1  Austerlitz  1805     FRENCH        75000    Allies        89000  0.84  0.84
# 2   Auerstadt  1806  Prussians        50000    FRENCH        30000  1.67   0.6
# 3    Borodino  1812     FRENCH       130000  Russians       120000  1.08  1.08
# 4     Dresden  1813     FRENCH       100000    Allies       150000  0.67  0.67
# 5     Leipzig  1813     ALLIES       300000    French       180000  1.67  1.67

# %%
len(df.index)
# Out:
# 49

# %%
df = df.dropna()

# %%
df.dtypes
# Out:
# Battle          object
# Date            object
# Attacker*       object
# Strength_Att    object
# Defender*       object
# Strength_Def    object
# A/D             object
# V/L             object
# dtype: object

# %%
import numpy as np
df[["Strength_Att", "Strength_Def"]] = df[["Strength_Att", "Strength_Def"]].astype(np.float).astype("Int64")

# %%
df.dtypes
# Out:
# Battle          object
# Date            object
# Attacker*       object
# Strength_Att     Int64
# Defender*       object
# Strength_Def     Int64
# A/D             object
# V/L             object
# dtype: object

# %%
df.at[8, "Strength_Def"] = 4594 # Battle of Buena Vista Wikipedia

# %%
df.head(10)
# Out:
#          Battle  Date     Attacker*  Strength_Att  Defender*  Strength_Def  \
# 1    Austerlitz  1805        FRENCH         75000     Allies         89000
# 2     Auerstadt  1806     Prussians         50000     FRENCH         30000
# 3      Borodino  1812        FRENCH        130000   Russians        120000
# 4       Dresden  1813        FRENCH        100000     Allies        150000
# 5       Leipzig  1813        ALLIES        300000     French        180000
# 6         Ligny  1815        FRENCH         77000  Prussians         83000
# 7      Waterloo  1815        ALLIES        129000     French         72000
# 8   Buena Vista  1847      Mexicans         16000  AMERICANS          4594
# 9   Cerro Gordo  1847     AMERICANS          8500   Mexicans         12000
# 10       Shiloh  1862  Confederates         40335      UNION         62642
#
#      A/D   V/L
# 1   0.84  0.84
# 2   1.67   0.6
# 3   1.08  1.08
# 4   0.67  0.67
# 5   1.67  1.67
# 6   0.93  0.93
# 7   1.79  1.79
# ...

# %%
df["Att_to_Def"] = round(df["Strength_Att"]/ df["Strength_Def"], 2)

# %%
df.head(10)
# Out:
#          Battle  Date     Attacker*  Strength_Att  Defender*  Strength_Def  \
# 1    Austerlitz  1805        FRENCH         75000     Allies         89000
# 2     Auerstadt  1806     Prussians         50000     FRENCH         30000
# 3      Borodino  1812        FRENCH        130000   Russians        120000
# 4       Dresden  1813        FRENCH        100000     Allies        150000
# 5       Leipzig  1813        ALLIES        300000     French        180000
# 6         Ligny  1815        FRENCH         77000  Prussians         83000
# 7      Waterloo  1815        ALLIES        129000     French         72000
# 8   Buena Vista  1847      Mexicans         16000  AMERICANS          4594
# 9   Cerro Gordo  1847     AMERICANS          8500   Mexicans         12000
# 10       Shiloh  1862  Confederates         40335      UNION         62642
#
#      A/D   V/L  Att_to_Def
# 1   0.84  0.84        0.84
# 2   1.67   0.6        1.67
# 3   1.08  1.08        1.08
# 4   0.67  0.67        0.67
# ...

# %%
df.insert(6, column = "Victor", value = ["A", "D", "A", "A", "A", "A", "A", "D", "A", "D", "D", "D", "D", "D", "A", "D", "A", 
                                        "A", "A", "A", "A", "A", "D", "A", "D", "D", "A", "A", "A", "A", "A", "A", "A", "A", 
                                         "D", "D", "D", "A", "A", "A", "A", "A"])

# %%
df.head(10)
# Out:
#          Battle  Date     Attacker*  Strength_Att  Defender*  Strength_Def  \
# 1    Austerlitz  1805        FRENCH         75000     Allies         89000
# 2     Auerstadt  1806     Prussians         50000     FRENCH         30000
# 3      Borodino  1812        FRENCH        130000   Russians        120000
# 4       Dresden  1813        FRENCH        100000     Allies        150000
# 5       Leipzig  1813        ALLIES        300000     French        180000
# 6         Ligny  1815        FRENCH         77000  Prussians         83000
# 7      Waterloo  1815        ALLIES        129000     French         72000
# 8   Buena Vista  1847      Mexicans         16000  AMERICANS          4594
# 9   Cerro Gordo  1847     AMERICANS          8500   Mexicans         12000
# 10       Shiloh  1862  Confederates         40335      UNION         62642
#
#    Victor   A/D   V/L  Att_to_Def
# 1       A  0.84  0.84        0.84
# 2       D  1.67   0.6        1.67
# 3       A  1.08  1.08        1.08
# ...

# %%
print("In 42 battles,", df.Victor.value_counts()[0], " attackers were successful.")
print("In 42 battles,", df.Victor.value_counts()[1], " defenders were successful.")
# Out:
# In 42 battles, 28  attackers were successful.
# In 42 battles, 14  defenders were successful.

# %%
print(len(df[df.Strength_Att < df.Strength_Def].Victor), "numerically inferior attackers;",
      df[df.Strength_Att < df.Strength_Def].Victor.value_counts()[0], "were successful.")
# Out:
# 15 numerically inferior attackers; 13 were successful.

# %%
print(len(df[(df.Victor == "A") & (df.Strength_Att > df.Strength_Def) | 
             (df.Victor == "D") & (df.Strength_Att < df.Strength_Def)]), "victors were numerically superior.")
# Out:
# 17 victors were numerically superior.

# %%
print(len(df[(df.Victor == "A") & (df.Strength_Att < df.Strength_Def) | 
       (df.Victor == "D") & (df.Strength_Att > df.Strength_Def)]), "victors were numerically inferior.")
# Out:
# 25 victors were numerically inferior.
